# %% [markdown]
# # Jeb Bush 2015 Data Exploration

# %% [markdown]
# ## Classes Visualization

# %%
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt
import os

# Code inspired by: https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f

# %%
in_directory = r'E:\Corpora\PII_Jeb_20190507'

# %%
df = pd.read_csv(r'E:\Corpora\PII_Jeb_20190507\tags_exploration.csv')
df.head()
# Out:
#                                    GUID                  minimum_label
# 0  fba3c4e5-719f-462b-811e-5dc96a694b5f  PII|ID|social_security_number
# 1  8af93e08-5904-4678-b1c2-985ef3287c45              PII|ID|bar_number
# 2  be0e3edc-5c20-4137-81b8-f5c074a11b69              PII|ID|bar_number
# 3  d1aba93c-dc66-4d52-b093-84b185476486           PII|ID|date_of_birth
# 4  e7a6b17d-e4d3-463f-a21a-b6e095d4ffa0           PII|ID|date_of_birth

# %% [markdown]
# ### Plot by Label Name

# %%
fig = plt.figure(figsize=(8,4))
df.groupby('minimum_label').GUID.count().plot.bar(ylim=0)
plt.show()

# %%
# Sanity Check for the Plot
df2=df.loc[df['minimum_label'] == 'PII|Biometric|handwritten_signature']
print(df2.shape)
df2=None
# Out:
# (634, 3)

# %%
df.columns
# Out:
# Index(['GUID', 'minimum_label'], dtype='object')

# %%
df.shape
# Out:
# (8763, 2)

# %%
# factorize is a quick way of creating a unique ID for each value in a column.
# The 0th element is an ndarray of IDs and will be equal to the number of rows
# in the DataFrame.
# The 1st element is an Index of labels in order of the IDs.
df['category_id'] = df['minimum_label'].factorize()[0]
list(df['category_id'])[:10]
# Out:
# [0, 1, 1, 2, 2, 3, 0, 0, 0, 3]

# %%
df.head(10)
# Out:
#                                    GUID                        minimum_label  \
# 0  fba3c4e5-719f-462b-811e-5dc96a694b5f        PII|ID|social_security_number
# 1  8af93e08-5904-4678-b1c2-985ef3287c45                    PII|ID|bar_number
# 2  be0e3edc-5c20-4137-81b8-f5c074a11b69                    PII|ID|bar_number
# 3  d1aba93c-dc66-4d52-b093-84b185476486                 PII|ID|date_of_birth
# 4  e7a6b17d-e4d3-463f-a21a-b6e095d4ffa0                 PII|ID|date_of_birth
# 5  0230a6fe-8e55-43fd-80b5-6380315b717f  PII|Biometric|handwritten_signature
# 6  30b2d6b4-ec3e-4918-8ff2-b0bb1a0a9531        PII|ID|social_security_number
# 7  60b1cb9c-8925-4055-9be0-0b221a220ab4        PII|ID|social_security_number
# 8  a974647a-a979-4751-ae32-f89b71ab8174        PII|ID|social_security_number
# 9  6e9c665c-9b24-4587-864a-fdcfb2ee6189  PII|Biometric|handwritten_signature
#
#    category_id
# 0            0
# 1            1
# 2            1
# 3            2
# 4            2
# 5            3
# 6            0
# 7            0
# 8            0
# 9            3

# %%
# Take the distinct of minimum_label and category_id using drop_duplicates
category_id_df = df[['minimum_label', 'category_id']].drop_duplicates().sort_values('category_id')
category_id_df.head(5)
# Out:
#                           minimum_label  category_id
# 0         PII|ID|social_security_number            0
# 1                     PII|ID|bar_number            1
# 3                  PII|ID|date_of_birth            2
# 5   PII|Biometric|handwritten_signature            3
# 13   PII|Health|applications_and_claims            4

# %%
# Convert minimum_label-category_id DataFrame to dictionary
category_to_id = dict(category_id_df.values)
# category_to_id
# {'PII|Account_Access|password_only': 22,
#  'PII|Account_Access|username_password': 12,

# %%
# Convert category_id-minimum_label DataFrame to dictionary
id_to_category = dict(category_id_df[['category_id','minimum_label']].values)
# id_to_category
# {0: 'PII|ID|social_security_number',
#  1: 'PII|ID|bar_number',

# %%
df.head()
# Out:
#                                    GUID                  minimum_label  \
# 0  fba3c4e5-719f-462b-811e-5dc96a694b5f  PII|ID|social_security_number
# 1  8af93e08-5904-4678-b1c2-985ef3287c45              PII|ID|bar_number
# 2  be0e3edc-5c20-4137-81b8-f5c074a11b69              PII|ID|bar_number
# 3  d1aba93c-dc66-4d52-b093-84b185476486           PII|ID|date_of_birth
# 4  e7a6b17d-e4d3-463f-a21a-b6e095d4ffa0           PII|ID|date_of_birth
#
#    category_id
# 0            0
# 1            1
# 2            1
# 3            2
# 4            2

# %% [markdown]
# ### Plot by Category ID

# %%
fig = plt.figure(figsize=(8,4))
df.groupby('category_id').GUID.count().plot.bar(ylim=0)
plt.show()

# %% [markdown]
# ## Feature Extraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Read DataFrame with text from a pickle
df2 = pd.read_pickle(os.path.join(in_directory,'df_pickle_001.pkl'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      51             with open(path, 'rb') as fh:
# ---> 52                 return pkl.load(fh)
#      53         except Exception:
#
# ImportError: No module named 'pandas.core.indexes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      56                 with open(path, 'rb') as fh:
# ---> 57                     return pc.load(fh, encoding=encoding, compat=False)
#      58
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     116
# --> 117         return up.load()
#     118     except:
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load(self)
#    1042                 assert isinstance(key, bytes_types)
# -> 1043                 dispatch[key[0]](self)
#    1044         except _Stop as stopinst:
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load_stack_global(self)
#    1350             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1351         self.append(self.find_class(module, name))
#    1352     dispatch[STACK_GLOBAL[0]] = load_stack_global
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in find_class(self, module, name)
#    1391                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1392         __import__(module, level=0)
#    1393         if self.proto >= 4:
#
# ImportError: No module named 'pandas.core.indexes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in read_pickle(path)
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     116
# --> 117         return up.load()
#     118     except:
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load(self)
#    1042                 assert isinstance(key, bytes_types)
# -> 1043                 dispatch[key[0]](self)
#    1044         except _Stop as stopinst:
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load_stack_global(self)
#    1350             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1351         self.append(self.find_class(module, name))
#    1352     dispatch[STACK_GLOBAL[0]] = load_stack_global
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in find_class(self, module, name)
#    1391                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1392         __import__(module, level=0)
#    1393         if self.proto >= 4:
#
# ImportError: No module named 'pandas.core.indexes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      51             with open(path, 'rb') as fh:
# ---> 52                 return pkl.load(fh)
#      53         except Exception:
#
# ImportError: No module named 'pandas.core.indexes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      56                 with open(path, 'rb') as fh:
# ---> 57                     return pc.load(fh, encoding=encoding, compat=False)
#      58
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     116
# --> 117         return up.load()
#     118     except:
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load(self)
#    1042                 assert isinstance(key, bytes_types)
# -> 1043                 dispatch[key[0]](self)
#    1044         except _Stop as stopinst:
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load_stack_global(self)
#    1350             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1351         self.append(self.find_class(module, name))
#    1352     dispatch[STACK_GLOBAL[0]] = load_stack_global
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in find_class(self, module, name)
#    1391                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1392         __import__(module, level=0)
#    1393         if self.proto >= 4:
#
# ImportError: No module named 'pandas.core.indexes'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-b6d1ef53d4a6> in <module>()
#       1 # Read DataFrame with text from a pickle
# ----> 2 df2 = pd.read_pickle(os.path.join(in_directory,'df_pickle_001.pkl'))
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in read_pickle(path)
#      66     except:
#      67         if PY3:
# ---> 68             return try_read(path, encoding='latin1')
#      69         raise
#      70
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      60             except:
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#      64     try:
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     115         up.is_verbose = is_verbose
#     116
# --> 117         return up.load()
#     118     except:
#     119         raise
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load(self)
#    1041                     raise EOFError
#    1042                 assert isinstance(key, bytes_types)
# -> 1043                 dispatch[key[0]](self)
#    1044         except _Stop as stopinst:
#    1045             return stopinst.value
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in load_stack_global(self)
#    1349         if type(name) is not str or type(module) is not str:
#    1350             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1351         self.append(self.find_class(module, name))
#    1352     dispatch[STACK_GLOBAL[0]] = load_stack_global
#    1353
#
# C:\Program Files\Anaconda3-420\lib\pickle.py in find_class(self, module, name)
#    1390             elif module in _compat_pickle.IMPORT_MAPPING:
#    1391                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1392         __import__(module, level=0)
#    1393         if self.proto >= 4:
#    1394             return _getattribute(sys.modules[module], name)[0]
#
# ImportError: No module named 'pandas.core.indexes'

# %% [markdown]
# ### TF-IDF vectorizer
# `sublinear_df` is set to `True` to use a logarithmic form for frequency.
# `min_df` is the minimum numbers of documents a word must be present in to be kept.
# `norm` is set to `34`, to ensure all our feature vectors have a euclidian norm of 1.
# `ngram_range` is set to `(1, 2)` to indicate that we want to consider both unigrams and bigrams.
# `stop_words` is set to `"english"` to remove all common pronouns `("a", "the", ...)` to reduce the number of noisy features.

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='34', encoding='utf-8', ngram_range=(1, 2), stop_words=None)

features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
labels = df.category_id
features.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-cb70cc5223c8> in <module>()
#       1 tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='34', encoding='utf-8', ngram_range=(1, 2), stop_words=None)
#       2
# ----> 3 features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
#       4 labels = df.category_id
#       5 features.shape
#
# C:\Program Files\Anaconda3-420\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Consumer_complaint_narrative'
